# %% [markdown]
# <h1 align='center'>Synthetic Data Generation and Unsloth Tutorial</h1>

# %% [markdown]
# ## 📚 Table of Contents:
#
# - [Synthetic Data Kit: Data Generation](#synthetic-data-generation)
# - [Unsloth: Fine-Tuning and saving the model](#fine-tuning)
#
# ## Synthetic Data Generation
#
# In this section, we use the CLI from synthetic-data-kit to generate datasets

# %% [markdown]
# ### Testing Synthetic Data Kit Command
#
# Please make sure you are running vllm by opening a terminal and typing `vllm serve Unsloth/Llama-3.3-70B-Instruct   --port 8001   --max-model-len 48000   --gpu-memory-utilization 0.85`

# %%
# !synthetic-data-kit --help
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
#
#  Usage: synthetic-data-kit [OPTIONS] COMMAND [ARGS]...
#
#  A toolkit for preparing synthetic datasets for fine-tuning LLMs
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --config              -c      PATH  Path to configuration file               │
# │ --install-completion                Install completion for the current       │
# │                                     shell.                                   │
# │ --show-completion                   Show completion for the current shell,   │
# │                                     to copy it or customize the              │
# │                                     installation.                            │
# │ --help                              Show this message and exit.              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ───────────────────────────────────────────────────────────────────╮
# │ system-check   Check if the selected LLM provider's server is running.       │
# │ ingest         Parse documents (PDF, HTML, YouTube, DOCX, PPT, TXT) into     │
# │                clean text.                                                   │
# │ create         Generate content from text using local LLM inference.         │
# │ curate         Clean and filter content based on quality.                    │
# │ save-as        Convert to different formats for fine-tuning.                 │
# │ server         Start a web interface for the Synthetic Data Kit.             │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### Exploring Synthetic Data Kit CLI
#
# This command displays the help menu for the `synthetic-data-kit` CLI tool, showing available commands:
# - **system-check**: Verify LLM provider server is running
# - **ingest**: Parse documents (PDF, HTML, YouTube, etc.) into clean text
# - **create**: Generate synthetic content (Q&A pairs, instructions, etc.) using LLM
# - **curate**: Filter and clean generated content based on quality scores
# - **save-as**: Convert data to different formats (fine-tuning format, JSON, etc.)
# - **server**: Launch web interface for the toolkit

# %%
# !synthetic-data-kit -c tutorial_config.yaml system-check
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: tutorial_config.yaml
# Config has LLM provider set to: vllm
# Environment variable check:
# API_ENDPOINT_KEY: Not found
# get_llm_provider returning: vllm
#  vLLM server is running at http://localhost:8001/v1
# Available models: {'object': 'list', 'data': [{'id':
# 'Unsloth/Llama-3.3-70B-Instruct', 'object': 'model', 'created': 1761581933,
# 'owned_by': 'vllm', 'root': 'Unsloth/Llama-3.3-70B-Instruct', 'parent': None,
# 'max_model_len': 48000, 'permission': [{'id':
# 'modelperm-4c51196734e345f4b903c101244ad9fb', 'object': 'model_permission',
# 'created': 1761581933, 'allow_create_engine': False, 'allow_sampling': True,
# 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True,
# 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking':
# False}]}]}
# ⠋ Checking vLLM server at http://localhost:8001/v1...

# %% [markdown]
# ### Verifying LLM Server Status
#
# This command checks if the vLLM server is running and accessible at `http://localhost:8001/v1`. It displays:
# - Server status and endpoint
# - Available models (here: Unsloth/Llama-3.3-70B-Instruct)
# - Model configuration (max context length: 48000 tokens)
#
# The system is configured to use the vLLM provider as specified in `tutorial_config.yaml`.

# %%
# %%bash
# mkdir -p logical_reasoning/{sources,data/{input,parsed,generated,curated,final}}
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# job-working-directory: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# mkdir: cannot create directory ‘logical_reasoning’: No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'mkdir -p logical_reasoning/{sources,data/{input,parsed,generated,curated,final}}\n')
#
# File /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py:348, in ScriptMagics.shebang(self, line, cell)
#     343 if args.raise_error and p.returncode != 0:
#     344     # If we get here and p.returncode is still None, we must have
#     345     # killed it but not yet seen its return code. We don't wait for it,
#     346     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     347     rc = p.returncode or -9
# --> 348     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'mkdir -p logical_reasoning/{sources,data/{input,parsed,generated,curated,final}}\n'' returned non-zero exit status 1.

# %% [markdown]
# ### Creating Project Directory Structure
#
# This command creates a well-organized directory structure for the logical reasoning project:
# - `sources/`: Store original source documents (PDFs, etc.)
# - `data/input/`: Input files for processing
# - `data/parsed/`: Parsed text files after document ingestion
# - `data/generated/`: Generated synthetic Q&A pairs
# - `data/curated/`: Quality-filtered data after curation
# - `data/final/`: Final formatted data ready for fine-tuning

# %%
cd logical_reasoning
# Out:
# /workspace/AIAC/logical_reasoning

# %% [markdown]
# ### Navigating to Project Directory
#
# Changes the current working directory to `logical_reasoning/` where all subsequent operations will take place.

# %%
# !wget -P sources/ -q --show-progress   "https://www.csus.edu/indiv/d/dowdenb/4/logical-reasoning-archives/logical-reasoning-2017-12-02.pdf"   "https://people.cs.umass.edu/~pthomas/solutions/Liar_Truth.pdf"
# Out:
# logical-reasoning-2 100%[===================>]   5.53M  1.36MB/s    in 4.5s
# Liar_Truth.pdf      100%[===================>] 327.61K  --.-KB/s    in 0.1s

# %% [markdown]
# ### Downloading Source Documents
#
# Downloads two PDF documents related to logical reasoning and liar/truth puzzles:
# 1. "Logical Reasoning" textbook from CSU Sacramento
# 2. "Liar and Truth Teller Puzzles" from UMass
#
# These documents will serve as the knowledge base for generating synthetic training data. The `-q` flag runs wget in quiet mode, and `--show-progress` displays a progress bar.

# %%
# !cp sources/* data/input/

# %% [markdown]
# ### Copying Source Files to Input Directory
#
# Copies all downloaded source documents from `sources/` to `data/input/` to prepare them for the ingestion pipeline.

# %%
# !synthetic-data-kit ingest ./data/input/
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Processing directory: ./data/input/
# Found 14 supported files to process
# ✓ Blood-Relations-Questions-and-Answers.pdf
# ✓ Blood_Relation_PDF_Set_1.pdf
# ✓ Blood_Relation_PDF_Set_2.pdf
# ✓ Blood_Relation_Quiz_36.pdf
# ✓ Liar_Truth.pdf
# ✓ blood-relation-free-pdf-for-upcoming-prelims-exams.pdf
# ✓ blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams.pdf
# ✓ blood_relations_medium_100.pdf
# ✓ circular-seating-arrangement-free-pdf-for-upcoming-prelims-exams.pdf
# ✓ linear-seating-arrangement-free-pdf-for-upcoming-prelims-exams.pdf
# WARNING:pdfminer.pdfinterp:Cannot set gray non-stroke color because /'P12' is an invalid float value
# ✓ logical-reasoning-2017-12-02.pdf
# ✓ parallel-rows-seating-arrangement-free-pdf-for-upcoming-prelims-exams.pdf
# ✓ seating_arrangements_medium_100.pdf
# ✓
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims.pdf
#
# ==================================================
# Processing Summary:
# Total files: 14
# Successful: 14
# Failed: 0
# ==================================================
# ✅ All files processed successfully!

# %% [markdown]
# ### Ingesting and Parsing Documents
#
# This command processes the PDF files in `data/input/` using the synthetic-data-kit's **ingest** command:
# - Extracts text content from PDFs
# - Cleans and normalizes the text
# - Saves parsed text files to `data/parsed/`
#
# The output shows successful processing of 2 PDF files (Liar_Truth.pdf and logical-reasoning-2017-12-02.pdf).

# %% [markdown]
# Note: This will take about 10 minutes, set `--verbose` flag to see progress or reduce the `num-pairs` for a faster test

# %%
# !synthetic-data-kit -c ../tutorial_config.yaml create ./data/parsed/ --type qa --num-pairs 100 --verbose
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: ../tutorial_config.yaml
# Config has LLM provider set to: vllm
# get_llm_provider returning: vllm
# 🔗 Using vllm provider
# Processing directory: ./data/parsed/ for qa generation
# Found 14 qa files to process
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# L Using vllm provider0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# Generating document summary...━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:00INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (780 chars)
# Generating QA pairs...m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06
# Document split into 3 chunks━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06
# Using batch size of 16m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06
# Processing 3 chunks to generate QA pairs...━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06
# Processing batch 1/1 with 3 chunks━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:065lGenerating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:00:06INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 3 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:02:28INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:46 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:25 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 12327
# Successfully parsed 41 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
#   Generated 41 pairs from chunk 1 (total: 41/100)━━━━━━━━━━━━   0% (0/14) 0:05:32
# Parsing response of length 8890━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Successfully parsed 35 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
#   Generated 35 pairs from chunk 2 (total: 76/100)━━━━━━━━━━━━   0% (0/14) 0:05:32
# Parsing response of length 10390━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Successfully parsed 34 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
#   Generated 24 pairs from chunk 3 (total: 100/100)━━━━━━━━━━━   0% (0/14) 0:05:32
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:25 -:--:--
# Generated 100 QA pairs total (requested: 100)
# Saving result to  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# data/generated/Blood-Relations-Questions-and-Answers_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json   0% (0/14) 0:05:32
# Successfully wrote result to ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# data/generated/Blood-Relations-Questions-and-Answers_qa_pairs.json
# ✓ Generated qa from Blood-Relations-Questions-and-Answers.txt -> % (0/14) 0:05:32
# Blood-Relations-Questions-and-Answers_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# L Using vllm provider0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Generating document summary...━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/14) 0:05:32INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (702 chars)
# Generating QA pairs...━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37
# Document split into 11 chunks╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37
# Using batch size of 16m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37
# Processing 11 chunks to generate QA pairs...━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37
# Processing batch 1/1 with 11 chunks━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:05:37INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 11 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:54 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:07:40INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:08:32INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:09:38INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:10:06INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:10:41INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:11:20INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:06:28 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:07:23 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:13:52INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:08:46 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 5337
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 1 (total: 9/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 718591m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 2 (total: 18/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 543291m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 3 (total: 27/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 683191m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 4 (total: 36/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 284691m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 5 (total: 45/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 342091m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 6 (total: 54/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 393591m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 7 (total: 63/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 472291m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 8 (total: 72/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 529391m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 9 (total: 81/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 481291m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 10 (total: 90/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Parsing response of length 305791m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully parsed 9 QA pairs╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
#   Generated 9 pairs from chunk 11 (total: 99/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:08:46 -:--:--3
# Generated 99 QA pairs total (requested: 100)
# Saving result to data/generated/Blood_Relation_PDF_Set_1_qa_pairs.json━━━━━━━━━   7% (1/14) 0:14:23
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Successfully wrote result to ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# data/generated/Blood_Relation_PDF_Set_1_qa_pairs.json
# ✓ Generated qa from Blood_Relation_PDF_Set_1.txt -> ━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Blood_Relation_PDF_Set_1_qa_pairs.json
# Loading config from: ../tutorial_config.yaml╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# L Using vllm provider1m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Generating document summary...╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23
# Generating qa content ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/14) 0:14:23INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (748 chars)
# Generating QA pairs...m━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28
# Document split into 9 chunks╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28
# Using batch size of 16m━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28
# Processing 9 chunks to generate QA pairs...━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28
# Processing batch 1/1 with 9 chunks90m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:14:28INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 9 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:15:37INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:16:51INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:17:49INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:19:22INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:20:04INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:20:57INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:21:44INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:08:02 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 6692
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 1 (total: 11/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 7790m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 12 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 12 pairs from chunk 2 (total: 23/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 6064m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 3 (total: 34/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 9349m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 4 (total: 45/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 4175m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 5 (total: 56/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 5571m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 6 (total: 67/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 4453m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 7 (total: 78/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 4935m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 8 (total: 89/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Parsing response of length 6776m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully parsed 11 QA pairsm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
#   Generated 11 pairs from chunk 9 (total: 100/100)━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:09:06 -:--:--5
# Generated 100 QA pairs total (requested: 100)
# Saving result to data/generated/Blood_Relation_PDF_Set_2_qa_pairs.json━━━━━━━━━  14% (2/14) 0:23:35
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Successfully wrote result to ╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# data/generated/Blood_Relation_PDF_Set_2_qa_pairs.json
# ✓ Generated qa from Blood_Relation_PDF_Set_2.txt -> ━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Blood_Relation_PDF_Set_2_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Config has LLM provider set to: vllmm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# L Using vllm provider1m━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Loading config from: ../tutorial_config.yaml90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Config has LLM provider set to: vllmm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Generating document summary...0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35
# Generating qa content ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  14% (2/14) 0:23:35INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (775 chars)
# Generating QA pairs...m━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40
# Document split into 1 chunks━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40
# Using batch size of 16m━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40
# Processing 1 chunks to generate QA pairs...0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40
# Processing batch 1/1 with 1 chunksm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:23:40INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 1 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 14831
# Falling back to regex pattern matching0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Extracted 80 QA pairs with regex╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
#   Generated 80 pairs from chunk 1 (total: 80/100)m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:42 -:--:--3
# Generated 80 QA pairs total (requested: 100)
# Saving result to data/generated/Blood_Relation_Quiz_36_qa_pairs.json━━━━━━━━━━━  21% (3/14) 0:26:23
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Successfully wrote result to data/generated/Blood_Relation_Quiz_36_qa_pairs.json  21% (3/14) 0:26:23
# ✓ Generated qa from Blood_Relation_Quiz_36.txt -> ━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Blood_Relation_Quiz_36_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Config has LLM provider set to: vllm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# L Using vllm provider1m━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Loading config from: ../tutorial_config.yamlm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Config has LLM provider set to: vllm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Generating document summary...━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23
# Generating qa content ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  21% (3/14) 0:26:23INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (773 chars)
# Generating QA pairs...m━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28
# Document split into 1 chunks━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28
# Using batch size of 16m━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28
# Processing 1 chunks to generate QA pairs...━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28
# Processing batch 1/1 with 1 chunks╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:26:28INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 1 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 6936
# Successfully parsed 10 QA pairs━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
#   Generated 10 pairs from chunk 1 (total: 10/100)90m━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:02 -:--:--1
# Generated 10 QA pairs total (requested: 100)
# Saving result to data/generated/Liar_Truth_qa_pairs.json━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Successfully wrote result to data/generated/Liar_Truth_qa_pairs.json━━━━━━━━━━━  29% (4/14) 0:27:31
# ✓ Generated qa from Liar_Truth.txt -> Liar_Truth_qa_pairs.json━━━━━━━━  29% (4/14) 0:27:31
# Loading config from: ../tutorial_config.yaml━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Config has LLM provider set to: vllmm╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# L Using vllm provider1m━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Config has LLM provider set to: vllmm╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Generating document summary...━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31
# Generating qa content ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  29% (4/14) 0:27:31INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (699 chars)
# Generating QA pairs...m━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36
# Document split into 5 chunks━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36
# Using batch size of 16m━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36
# Processing 5 chunks to generate QA pairs...1m╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36
# Processing batch 1/1 with 5 chunks━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:27:36INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:14 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:29:41INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:31:00INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:32:05INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 7871
# Successfully parsed 20 QA pairs━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
#   Generated 20 pairs from chunk 1 (total: 20/100)m━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Parsing response of length 4849━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Successfully parsed 20 QA pairs━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
#   Generated 20 pairs from chunk 2 (total: 40/100)m━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Parsing response of length 8057━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Successfully parsed 21 QA pairs━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
#   Generated 21 pairs from chunk 3 (total: 61/100)m━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Parsing response of length 6549━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Successfully parsed 20 QA pairs━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
#   Generated 20 pairs from chunk 4 (total: 81/100)m━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Parsing response of length 6768━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Successfully parsed 20 QA pairs━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
#   Generated 19 pairs from chunk 5 (total: 100/100)━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:31 -:--:--7
# Generated 100 QA pairs total (requested: 100)
# Saving result to  ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# data/generated/blood-relation-free-pdf-for-upcoming-prelims-exams_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Successfully wrote result to ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# data/generated/blood-relation-free-pdf-for-upcoming-prelims-exams_qa_pairs.json
# ✓ Generated qa from blood-relation-free-pdf-for-upcoming-prelims-exams.txt -> 5m 36% (5/14) 0:33:07
# blood-relation-free-pdf-for-upcoming-prelims-exams_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Config has LLM provider set to: vllm╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# L Using vllm provider1m━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Loading config from: ../tutorial_config.yamlm╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Config has LLM provider set to: vllm╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Generating document summary...━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07
# Generating qa content ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━  36% (5/14) 0:33:07INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (744 chars)
# Generating QA pairs...m━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12
# Document split into 19 chunks━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12
# Using batch size of 16m━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12
# Processing 19 chunks to generate QA pairs...╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12
# Processing batch 1/2 with 16 chunks━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:33:12INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 16 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:22 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:07 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:35:03INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:35:28INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:36:00INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:36:33INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:37:10INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:37:39INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:57 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:38:57INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:39:30INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:06:51 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:07:26 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:08:12 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:41:57INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:09:13 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 2257
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 1 (total: 5/100)m╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 4938━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 2 (total: 10/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 4805━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 3 (total: 15/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 2408━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 4 (total: 20/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3233━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 5 (total: 25/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3385━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 6 (total: 30/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3471━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 7 (total: 35/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 2689━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 8 (total: 40/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3171━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 9 (total: 45/100)╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 5108━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 10 (total: 50/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3263━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 11 (total: 55/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3489━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 12 (total: 60/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3146━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 13 (total: 65/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 4727━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 14 (total: 70/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3368━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 15 (total: 75/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Parsing response of length 3162━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
#   Generated 5 pairs from chunk 16 (total: 80/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Processing batch 2/2 with 3 chunks━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:25INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 3 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:42:52INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:26INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:10:43 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 2890
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
#   Generated 5 pairs from chunk 17 (total: 85/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Parsing response of length 3499━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
#   Generated 5 pairs from chunk 18 (total: 90/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Parsing response of length 3001━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Successfully parsed 5 QA pairs━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
#   Generated 5 pairs from chunk 19 (total: 95/100)━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:10:43 -:--:--6
# Generated 95 QA pairs total (requested: 100)
# Saving result to  ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# data/generated/blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams_q
# a_pairs.json
# Successfully wrote test file to data/generated/test_write.json━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Successfully wrote result to ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# data/generated/blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams_q
# a_pairs.json
# ✓ Generated qa from ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams.txt ->
# blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Config has LLM provider set to: vllm━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# L Using vllm provider1m━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Loading config from: ../tutorial_config.yaml╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Config has LLM provider set to: vllm━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Generating document summary...━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56
# Generating qa content ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  43% (6/14) 0:43:56INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (718 chars)
# Generating QA pairs...m━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01
# Document split into 33 chunks━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01
# Using batch size of 16m━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01
# Processing 33 chunks to generate QA pairs...0m╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01
# Processing batch 1/3 with 16 chunks━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:01INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 16 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:44:24INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:37 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:50 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:08 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:23 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:37 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:00 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:15 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:46:33INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:46:49INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:02 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:47:17INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:28 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:42 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% (7/14) 0:47:58INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# ...
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 40 (total: 80/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 959━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 41 (total: 82/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 1181━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 42 (total: 84/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 1842━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 43 (total: 86/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 2832━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 44 (total: 88/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 2917━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 45 (total: 90/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 1614━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 46 (total: 92/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 2295━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 47 (total: 94/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Parsing response of length 1745━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
#   Generated 2 pairs from chunk 48 (total: 96/100)━━━━━╸━━━━━  86% (12/14) 1:42:29
# Processing batch 4/4 with 3 chunks━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:42:29INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 3 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:16:05 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:16:23 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:16:38 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 2483
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
#   Generated 2 pairs from chunk 49 (total: 98/100)━━━━━╸━━━━━  86% (12/14) 1:43:24
# Parsing response of length 1681━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Successfully parsed 2 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
#   Generated 2 pairs from chunk 50 (total: 100/100)━━━━╸━━━━━  86% (12/14) 1:43:24
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:16:38 -:--:--4
# Generated 100 QA pairs total (requested: 100)
# Saving result to data/generated/seating_arrangements_medium_100_qa_pairs.json━  86% (12/14) 1:43:24
# Successfully wrote test file to data/generated/test_write.jsonm╸━━━━━  86% (12/14) 1:43:24
# Successfully wrote result to ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# data/generated/seating_arrangements_medium_100_qa_pairs.json
# ✓ Generated qa from seating_arrangements_medium_100.txt -> ━━━━━  86% (12/14) 1:43:24
# seating_arrangements_medium_100_qa_pairs.json
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# L Using vllm provider1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Generating document summary...━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━  86% (12/14) 1:43:24INFO:synthetic_data_kit.models.llm_client:Sending request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Summary generated (755 chars)
# Generating QA pairs...m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28
# Document split into 17 chunks━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28
# Using batch size of 16m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28
# Processing 17 chunks to generate QA pairs...━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28
# Processing batch 1/2 with 16 chunks━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:43:28INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 16 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:44:06INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:11 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:29 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:09 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:34 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:07 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:40 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:27 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:04 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:36 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:06:06 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:50:02INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:50:40INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:51:19INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:51:53INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 4010
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 1 (total: 6/100)━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 3610━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 2 (total: 12/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 1914━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 3 (total: 18/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4364━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 4 (total: 24/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 2930━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 5 (total: 30/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 3734━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 6 (total: 36/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4016━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 7 (total: 42/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 5266━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 8 (total: 48/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4344━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 9 (total: 54/100)━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 3588━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 10 (total: 60/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 3506━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 11 (total: 66/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 2958━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 12 (total: 72/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4295━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 13 (total: 78/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4644━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 14 (total: 84/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 4480━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 15 (total: 90/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Parsing response of length 3662━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
#   Generated 6 pairs from chunk 16 (total: 96/100)━━━━━━━━╺━━  93% (13/14) 1:52:27
# Processing batch 2/2 with 1 chunks━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:52:27INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 1 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:53:22INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Parsing response of length 5826
# Successfully parsed 6 QA pairs━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:53:22
#   Generated 4 pairs from chunk 17 (total: 100/100)━━━━━━━╺━━  93% (13/14) 1:53:22
# Generating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:09:53 -:--:--2
# Generated 100 QA pairs total (requested: 100)
# Saving result to  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:53:22
# data/generated/triangle-seating-arrangement-with-two-variable-questions-speciall
# y-for-sbi-po-prelims_qa_pairs.json
# Successfully wrote test file to data/generated/test_write.json╺━━  93% (13/14) 1:53:22
# Successfully wrote result to ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:53:22
# data/generated/triangle-seating-arrangement-with-two-variable-questions-speciall
# y-for-sbi-po-prelims_qa_pairs.json
# ✓ Generated qa from ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (13/14) 1:53:22
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims.txt ->
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims_qa_pairs.json
# Generating qa content ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% (14/14) 1:53:22 93% (13/14) 1:53:22
#
# ==================================================
# Content Generation Summary (qa):
# Total files: 14
# Successful: 14
# Failed: 0
# ==================================================
# ✅ All files processed successfully!

# %% [markdown]
# ### Generating Synthetic Q&A Pairs
#
# This command uses the synthetic-data-kit's **create** command to generate Q&A pairs from the parsed text:
# - Reads parsed text files from `data/parsed/`
# - Uses the vLLM provider with Llama-3.3-70B-Instruct model
# - Generates 50 Q&A pairs per file (`--num-pairs 50`)
# - Type is set to `qa` for question-answer pair generation
# - Outputs are saved to `data/generated/`
#
# The process chunks the text and generates questions with corresponding answers. This took about 10 minutes for the full run. Use `--verbose` flag to see detailed progress or reduce `--num-pairs` for faster testing.

# %%
# !synthetic-data-kit -c ../tutorial_config.yaml curate ./data/generated/ --threshold 7.0 --verbose
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: ../tutorial_config.yaml
# Config has LLM provider set to: vllm
# get_llm_provider returning: vllm
# 🔗 Using vllm provider
# Processing directory: ./data/generated/ for curation
# Found 15 JSON files to curate
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Processing 20 batches of QA pairs...━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Processing batch 1/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:00INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:18 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:34 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:00:47INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:01 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:14 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
#   {"question": "Richa introduces a boy to her mother, saying he is the son of (0/15) 0:01:14
# the daughter of the ...
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
#   {"question": "Ajit pointed at Abhijeet and said, 'I am the only son of one of /15) 0:01:14
# the sons of his fa...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
#   {"question": "In the same family, how is F related to B?", "answer": "F is the/15) 0:01:14
# aunt of B. Since ...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
#   {"question": "If T is the son of U, and U is the daughter of V, how is T 0m (0/15) 0:01:14
# related to V?", "answer...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
#   {"question": "If I is the father of J, and J is the brother of K, how is I  (0/15) 0:01:14
# related to K?", "answ...
# Processing batch 1m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Parsing ratings response of length 1561━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Raw response: '[\n  {"question": "Richa introduces a boy to her mother, saying 0/15) 0:01:14
# he is the son of the daughter of the father of her uncle. How is Richa related
# to the boy?", "answer": "Richa is the brother of the boy. The father of Richa\'s
# uncle is Richa\'s grandfather. The daughter of Richa\'s grandfather is Richa\'s
# mother. The son of Richa\'s mother is Richa\'s brother.", "rating": 9},\n
# {"question": "Ejaz is the son of Kismat. Bharat is the brother of Dharmesh, and
# Garima is Dharmesh\'s daughter. Kismat is married '
# JSON parse error for object: Extra data: line 1 column 364 (char 363)  0% (0/15) 0:01:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Processing batch 2m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Parsing ratings response of length 1431━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Raw response: '[\n  {"question": "Ajit pointed at Abhijeet and said, \'I am the /15) 0:01:14
# only son of one of the sons of his father.\' How is Ajit related to Abhijeet?",
# "answer": "Ajit is either the father or uncle of Abhijeet. Since Ajit is the
# only son of one of the sons of Abhijeet\'s father, Ajit can be either the father
# or uncle of Abhijeet.", "rating": 9},\n  {"question": "Sangeeta came across a
# photo and pointing towards a boy in it, Sangeeta said, \'He is the only son of
# the only daughter of my Grandfather.\' How is S'
# JSON parse error for object: Extra data: line 1 column 332 (char 331)  0% (0/15) 0:01:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Processing batch 3m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Parsing ratings response of length 1077━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Raw response: '[\n  {"question": "In the same family, how is F related to B?", 0/15) 0:01:14
# "answer": "F is the aunt of B. Since F is the daughter of A, and B is the son of
# G, F is the aunt of B.", "rating": 8},\n  {"question": "If A is the father of B,
# and B is the father of C, how is A related to C?", "answer": "A is the
# grandfather of C. Since A is the father of B, and B is the father of C, A is the
# grandfather of C.", "rating": 9},\n  {"question": "If X is the sister of Y, and
# Y is the brother of Z, how is X related to Z?'
# JSON parse error for object: Extra data: line 1 column 178 (char 177)  0% (0/15) 0:01:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Processing batch 4m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Parsing ratings response of length 1083━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Raw response: '[\n  {"question": "If T is the son of U, and U is the daughter of/15) 0:01:14
# V, how is T related to V?", "answer": "T is the grandson of V. Since T is the
# son of U, and U is the daughter of V, T is the grandson of V.", "rating": 9},\n
# {"question": "If W is the father of X, and X is the brother of Y, how is W
# related to Y?", "answer": "W is the father of Y. Since W is the father of X, and
# X is the brother of Y, W is the father of Y.", "rating": 9},\n  {"question": "If
# Z is the sister of A, and A is the brothe'
# JSON parse error for object: Extra data: line 1 column 216 (char 215)  0% (0/15) 0:01:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Processing batch 5m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Parsing ratings response of length 1093━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Raw response: '[\n  {"question": "If I is the father of J, and J is the brother /15) 0:01:14
# of K, how is I related to K?", "answer": "I is the father of K. Since I is the
# father of J, and J is the brother of K, I is the father of K.", "rating": 9},\n
# {"question": "If L is the sister of M, and M is the brother of N, how is L
# related to N?", "answer": "L is the sister of N. Since L is the sister of M, and
# M is the brother of N, L is the sister of N.", "rating": 9},\n  {"question": "If
# O is the brother of P, and P is the fathe'
# JSON parse error for object: Extra data: line 1 column 216 (char 215)  0% (0/15) 0:01:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Processing batch 2/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:01:14INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:28 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:41 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:54 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:03 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:12 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
#   {"question": "If X is the sister of Y, and Y is the sister of Z, how is X m (0/15) 0:02:12
# related to Z?", "answe...
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
#   {"question": "If M is the father of N, and N is the brother of O, how is M  (0/15) 0:02:12
# related to O?", "answ...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
#   {"question": "If B is the sister of C, and C is the brother of D, how is B  (0/15) 0:02:12
# related to D?", "answ...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
#   {"question": "If Q is the mother of R, and R is the mother of S, how is Q m (0/15) 0:02:12
# related to S?", "answe...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
#   {"question": "What is the profession of Honey's wife?", "answer": "Honey's  (0/15) 0:02:12
# wife is an Engineer."...
# Processing batch 6m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Parsing ratings response of length 1121━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Raw response: '[\n  {"question": "If X is the sister of Y, and Y is the sister 0/15) 0:02:12
# of Z, how is X related to Z?", "answer": "X is the sister of Z. Since X is the
# sister of Y, and Y is the sister of Z, X is the sister of Z.", "rating": 9},\n
# {"question": "If A is the brother of B, and B is the brother of C, how is A
# related to C?", "answer": "A is the brother of C. Since A is the brother of B,
# and B is the brother of C, A is the brother of C.", "rating": 9},\n
# {"question": "If D is the father of E, and E is the fath'
# JSON parse error for object: Extra data: line 1 column 214 (char 213)  0% (0/15) 0:02:12
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Processing batch 7m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Parsing ratings response of length 1081━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Raw response: '[\n  {"question": "If M is the father of N, and N is the brother /15) 0:02:12
# of O, how is M related to O?", "answer": "M is the father of O. Since M is the
# father of N, and N is the brother of O, M is the father of O.", "rating": 9},\n
# {"question": "If P is the sister of Q, and Q is the sister of R, how is P
# related to R?", "answer": "P is the sister of R. Since P is the sister of Q, and
# Q is the sister of R, P is the sister of R.", "rating": 9},\n  {"question": "If
# S is the mother of T, and T is the son of U'
# JSON parse error for object: Extra data: line 1 column 216 (char 215)  0% (0/15) 0:02:12
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Processing batch 8m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Parsing ratings response of length 1091━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Raw response: '[\n  {"question": "If B is the sister of C, and C is the brother /15) 0:02:12
# of D, how is B related to D?", "answer": "B is the sister of D. Since B is the
# sister of C, and C is the brother of D, B is the sister of D.", "rating": 8},\n
# {"question": "If E is the mother of F, and F is the daughter of G, how is E
# related to G?", "answer": "E is the wife of G. Since E is the mother of F, and F
# is the daughter of G, E is the wife of G.", "rating": 9},\n  {"question": "If H
# is the father of I, and I is the brother '
# JSON parse error for object: Extra data: line 1 column 216 (char 215)  0% (0/15) 0:02:12
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Processing batch 9m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Parsing ratings response of length 787━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Raw response: '[\n  {"question": "If Q is the mother of R, and R is the mother 0/15) 0:02:12
# of S, how is Q related to S?", "answer": "Q is the grandmother of S. Since Q is
# the mother of R, and R is the mother of S, Q is the grandmother of S.",
# "rating": 9},\n  {"question": "If a person is a knight, what can be concluded
# about their statements?", "answer": "A knight always tells the truth, so their
# statements can be trusted.", "rating": 8},\n  {"question": "How is the person
# related to Harish\'s wife?", "answer": "The person is'
# JSON parse error for object: Extra data: line 1 column 224 (char 223)  0% (0/15) 0:02:12
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Processing batch 10━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Parsing ratings response of length 767━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Raw response: '[\n  {"question": "What is the profession of Honey\'s wife?",  (0/15) 0:02:12
# "answer": "Honey\'s wife is an Engineer.", "rating": 2},\n  {"question": "Which
# statement is incorrect with respect to the blood relation given?", "answer":
# "The statement \'Harish is the husband of an Engineer\' is incorrect.",
# "rating": 4},\n  {"question": "If A and C are a married couple, and C is not the
# mother of B, what can be concluded about B\'s parentage?", "answer": "B\'s
# mother must be someone other than C, and since A and C are a m'
# JSON parse error for object: Extra data: line 1 column 111 (char 110)  0% (0/15) 0:02:12
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Processing batch 3/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:12INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:19 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:28 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:38 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:47 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:59 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
#   {"question": "How is E related to F?", "answer": "E is F's uncle.", "rating":
# 6},
#   {"question":...0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
#   {"question": "If a person has a child, what can be concluded about their 0m (0/15) 0:02:59
# relationship to that ch...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
#   {"question": "If a person is someone's niece, what can be concluded about m (0/15) 0:02:59
# their relationship?", ...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
#   {"question": "If two people are cousins, what can be concluded about their  (0/15) 0:02:59
# relationship?", "answ...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
#   {"question": "If a person has two children, what can be concluded about their /15) 0:02:59
# relationship to th...
# Processing batch 11━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Parsing ratings response of length 723━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Raw response: '[\n  {"question": "How is E related to F?", "answer": "E is F\'s /15) 0:02:59
# uncle.", "rating": 6},\n  {"question": "What is the profession of the person
# married to C?", "answer": "The person married to C is a Doctor.", "rating":
# 5},\n  {"question": "How is E related to A?", "answer": "The relationship
# between E and A cannot be determined.", "rating": 8},\n  {"question": "If a
# person is a knave, what can be concluded about their statements?", "answer": "A
# knave always lies, so their statements cannot be trusted.'
# JSON parse error for object: Extra data: line 1 column 81 (char 80)5m  0% (0/15) 0:02:59
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Processing batch 12━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Parsing ratings response of length 983━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Raw response: '[\n  {"question": "If a person has a child, what can be concluded/15) 0:02:59
# about their relationship to that child?", "answer": "A person who has a child is
# that child\'s parent.", "rating": 9},\n  {"question": "If two people are
# siblings, what can be concluded about their relationship?", "answer": "Two
# people who are siblings share a common parent and are each other\'s brother or
# sister.", "rating": 9},\n  {"question": "If a person is someone\'s uncle, what
# can be concluded about their relationship?", "answer"'
# JSON parse error for object: Extra data: line 1 column 178 (char 177)  0% (0/15) 0:02:59
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Processing batch 13━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Parsing ratings response of length 1064━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Raw response: '[\n  {"question": "If a person is someone\'s niece, what can be 0/15) 0:02:59
# concluded about their relationship?", "answer": "A person who is someone\'s
# niece is the child of that person\'s sibling.", "rating": 9},\n  {"question":
# "If two people are in a romantic partnership, what can be concluded about their
# relationship?", "answer": "Two people who are in a romantic partnership are each
# other\'s partner and may be married or unmarried.", "rating": 8},\n
# {"question": "If a person has a grandchild, what can be con'
# JSON parse error for object: Extra data: line 1 column 193 (char 192)  0% (0/15) 0:02:59
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Processing batch 14━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Parsing ratings response of length 1021━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Raw response: '[\n  {"question": "If two people are cousins, what can be  (0/15) 0:02:59
# concluded about their relationship?", "answer": "Two people who are cousins
# share a common grandparent and are each other\'s cousin.", "rating": 8},\n
# {"question": "If a person has a sibling, what can be concluded about their
# relationship to that sibling?", "answer": "A person who has a sibling shares a
# common parent with that sibling.", "rating": 9},\n  {"question": "If a person is
# someone\'s mother, what can be concluded about their relatio'
# JSON parse error for object: Extra data: line 1 column 200 (char 199)  0% (0/15) 0:02:59
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Processing batch 15━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Parsing ratings response of length 1243━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Raw response: '[\n  {"question": "If a person has two children, what can be m (0/15) 0:02:59
# concluded about their relationship to those children?", "answer": "A person who
# has two children is the parent of both of those children.", "rating": 9},\n
# {"question": "If two people are siblings and have a child, what can be concluded
# about their relationship to that child?", "answer": "Two people who are siblings
# and have a child are that child\'s parents, but they cannot be siblings and
# parents at the same time.", "rating": 8},\n  {"q'
# JSON parse error for object: Extra data: line 1 column 209 (char 208)  0% (0/15) 0:02:59
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Processing batch 4/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:02:59INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:12 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:24 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:36 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:48 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:58 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
#   {"question": "If two people are married and one of them has a child, what can /15) 0:03:58
# be concluded about...
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
#   {"question": "If D is male, and A is a female, what can be concluded about the/15) 0:03:58
# gender of E?", "a...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
#   {"question": "Given the statement 'C is the mother of F', what can be inferred/15) 0:03:58
# about the relatio...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
#   {"question": "If C is the mother of F, and A is the Grandmother of F, what can/15) 0:03:58
# be concluded abou...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
#   {"question": "Given the family tree notation, what does the symbol '\u2194' (0/15) 0:03:58
# represent?", "answer...
# Processing batch 16━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Parsing ratings response of length 1392━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Raw response: '[\n  {"question": "If two people are married and one of them has /15) 0:03:58
# a child, what can be concluded about their relationship to that child?",
# "answer": "Two people who are married and one of them has a child are that
# child\'s parents, but only if the child is the biological child of both
# spouses.", "rating": 7},\n  {"question": "If E and A are siblings, and A is a
# female, what can be concluded about E\'s gender?", "answer": "Since E and A are
# siblings, and A is a female, E can be either male or female. '
# JSON parse error for object: Extra data: line 1 column 303 (char 302)  0% (0/15) 0:03:58
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing batch 17━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Parsing ratings response of length 1205━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Raw response: '[\n  {"question": "If D is male, and A is a female, what can be 0/15) 0:03:58
# concluded about the gender of E?", "answer": "There is not enough information to
# determine the gender of E. The gender of D and A does not provide any
# information about the gender of E.", "rating": 9},\n  {"question": "Given the
# statement \'A is the Grandmother of F\', what can be inferred about the age of
# A?", "answer": "If A is the Grandmother of F, then A must be older than F.
# However, the exact age of A cannot be determined.", "rati'
# JSON parse error for object: Extra data: line 1 column 260 (char 259)  0% (0/15) 0:03:58
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing batch 18━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Parsing ratings response of length 1301━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Raw response: '[\n  {"question": "Given the statement \'C is the mother of F\', /15) 0:03:58
# what can be inferred about the relationship between C and E?", "answer": "If C
# is the mother of F, and E is a sibling of A, then C must be the mother of A as
# well. However, without more information about the family tree, the exact
# relationship between C and E cannot be determined.", "rating": 6},\n
# {"question": "If D is male, and B is a Doctor by profession, what can be
# concluded about the profession of D?", "answer": "There is no inf'
# JSON parse error for object: Extra data: line 1 column 355 (char 354)  0% (0/15) 0:03:58
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing batch 19━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Parsing ratings response of length 1191━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Raw response: '[\n  {"question": "If C is the mother of F, and A is the % (0/15) 0:03:58
# Grandmother of F, what can be concluded about the relationship between C and
# A?", "answer": "If C is the mother of F, and A is the Grandmother of F, then C
# must be the daughter of A.", "rating": 9},\n  {"question": "Given the family
# tree notation, what does the symbol \'-\' represent?", "answer": "The symbol
# \'-\' represents a female.", "rating": 8},\n  {"question": "If E and A are
# siblings, and A is a female, what can be concluded about the gend'
# JSON parse error for object: Extra data: line 1 column 250 (char 249)  0% (0/15) 0:03:58
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing batch 20━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Parsing ratings response of length 1090━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Raw response: '[\n  {"question": "Given the family tree notation, what does the /15) 0:03:58
# symbol \'\\u2194\' represent?", "answer": "The symbol \'\\u2194\' represents
# siblings.", "rating": 8},\n  {"question": "If A is a Teacher by profession, and
# E is an Engineer by profession, what can be concluded about the profession of
# B?", "answer": "There is no information provided about the profession of B. The
# statement only mentions the professions of A and E.", "rating": 9},\n
# {"question": "Given the statement \'C is the mother of F\', '
# JSON parse error for object: Extra data: line 1 column 156 (char 155)  0% (0/15) 0:03:58
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:58 -:--:--
# Rated 100 QA pairs
# Retained 85 pairs (threshold: 7.0)━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Average score: 8.0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# ✓ Curated Blood-Relations-Questions-and-Answers_qa_pairs.json ->  (0/15) 0:03:58
# Blood-Relations-Questions-and-Answers_qa_pairs_cleaned.json
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Loading config from: ../tutorial_config.yaml━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Config has LLM provider set to: vllm━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing 20 batches of QA pairs...━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Processing batch 1/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00 -:--:--
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% (0/15) 0:03:58INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:22 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:57 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:30 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:01:59 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:02:23 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
#   {"question": "How is M related to P?", "answer": "M is the father of the ━━   7% (1/15) 0:06:22
# spouse of O, and R is t...
# Response 2: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
#   {"question": "If Madhav has a son, then how will he be related to Krishna?", 0m   7% (1/15) 0:06:22
# "answer": "We know ...
# Response 3: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
#   {"question": "How is Sia related to Tur?", "answer": "To find out how Sia is 0m   7% (1/15) 0:06:22
# related to Tur, we ...
# Response 4: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
#   {"question": "How many male members are there in the family?", "answer": "To 0m   7% (1/15) 0:06:22
# determine the numbe...
# Response 5: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
#   {"question": "How is C related to M, given the information about their family m   7% (1/15) 0:06:22
# members and relati...
# Processing batch 1m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Parsing ratings response of length 2202m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Raw response: '[\n  {"question": "How is M related to P?", "answer": "M is the 0m   7% (1/15) 0:06:22
# father of the spouse of O, and R is the maternal uncle of S. Since P and S are
# sisters, and M is the brother-in-law of R, M must be the father of O\'s spouse,
# who is also the parent of P and S. Therefore, M is the grandfather of P.",
# "rating": 8},\n  {"question": "If J is the grandchild of M, then how is N
# related to J?", "answer": "Since M is the father of O\'s spouse, and Q is the
# son of N, we can deduce that N is the spouse of M. The'
# JSON parse error for object: Extra data: line 1 column 305 (char 304)━━━━━━━━━━━━   7% (1/15) 0:06:22
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Processing batch 2m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Parsing ratings response of length 3449m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Raw response: '[\n  {"question": "If Madhav has a son, then how will he be ━━   7% (1/15) 0:06:22
# related to Krishna?", "answer": "We know that Kanha is the grandmother of Hari,
# so she belongs to the first generation. If Madhav has a son, then Madhav must
# belong to the second generation, since his son would belong to the third
# generation. Therefore, Madhav is the child of one of Krishna\'s siblings, or
# Krishna\'s spouse, making Madhav\'s son the nephew or grandchild of Krishna.",
# "rating": 8},\n  {"question": "How is Qutub related to Naa'
# JSON parse error for object: Extra data: line 1 column 452 (char 451)━━━━━━━━   7% (1/15) 0:06:22
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Processing batch 3m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Parsing ratings response of length 3539m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Raw response: '[\n  {"question": "How is Sia related to Tur?", "answer": "To    7% (1/15) 0:06:22
# find out how Sia is related to Tur, we look at the given relationships. Tur is
# married to Dep, who is the aunt of Han. Sia and Rai are cousins of Jay, and Map
# and Eva are uncles of Sia and Han. This implies that Sia and Han are in the same
# generation and are related through their parents. Since Tur is an aunt of Han,
# and considering the family structure with married couples and their children,
# Tur would be an aunt of Sia as well if Sia'
# JSON parse error for object: Extra data: line 1 column 570 (char 569)━━━━━━━━   7% (1/15) 0:06:22
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Processing batch 4m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Parsing ratings response of length 2887m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Raw response: '[\n  {"question": "How many male members are there in the ━━━━   7% (1/15) 0:06:22
# family?", "answer": "To determine the number of male members in the family, we
# analyze the given information: Minu is the daughter-in-law of Joya, Tiya is the
# grandmother of Drona, Heer is the sister-in-law of Joya, Gaur has two children
# (Ali and Drona), and Tiya is the only sibling of Heer. From this, we can infer
# the following males: Ali, Drona (Gaur\'s children), and potentially Joya\'s
# husband (since Minu is Joya\'s daughter-in-law) and G'
# JSON parse error for object: Extra data: line 1 column 807 (char 806)━━━━━━━━   7% (1/15) 0:06:22
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Processing batch 5m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Parsing ratings response of length 2739m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Raw response: '[\n  {"question": "How is C related to M, given the information 0m   7% (1/15) 0:06:22
# about their family members and relationships?", "answer": "From the statements,
# we know Z is C\'s father, and M says N is his daughter-in-law, but there\'s no
# direct statement linking C to M. However, understanding that L says C is his
# niece and considering the relationships, we can infer connections but need a
# direct link to accurately determine the relationship between C and M.",
# "rating": 7},\n  {"question": "How many female members '
# JSON parse error for object: Extra data: line 1 column 455 (char 454)━━━━━━━━   7% (1/15) 0:06:22
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Processing batch 2/4━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Sending batch request with 5 itemsm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:22INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:06:54INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:31 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:47 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:07:59INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
#   {"question": "How is W related to K based on the given expression ━━━━━━━━━   7% (1/15) 0:08:16
# J@K!T*W?X#Z?", "answer": "Usin...
# Response 2: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
#   {"question": "How is Abhi related to Bati?", "answer": "Abhi is the ━━━━━━━   7% (1/15) 0:08:16
# grandmother of Mahe, and sin...
# Response 3: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
#   {
#     "question": "Who among the following is the wife of V?",
#     "answer": "Given V is the onl...━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Response 4: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
#   {"question": "How is the one who uses Nokia related to the one who uses ━━━   7% (1/15) 0:08:16
# Vivo?", "answer": "The o...
# Response 5: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
#   {"question": "If Radhey is the son-in-law of Krishna and Hari has an uncle,    7% (1/15) 0:08:16
# what is the relation...
# Processing batch 6m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Parsing ratings response of length 3000m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Raw response: '[\n  {"question": "How is W related to K based on the given ━━   7% (1/15) 0:08:16
# expression J@K!T*W?X#Z?", "answer": "Using the given meanings: J@K means J is
# the son of K, K!T means K is the mother of T, T*W means T is the brother of W,
# and W?X means W is the daughter of X. So, if T is the brother of W and K is the
# mother of T, then W must also be a child of K, making W the daughter or son of
# K. However, since W?X indicates W is the daughter of X, W is specifically the
# daughter of X, but in relation to K, W would be'
# JSON parse error for object: Extra data: line 1 column 586 (char 585)━━━━━━━━   7% (1/15) 0:08:16
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Processing batch 7m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Parsing ratings response of length 3668m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Raw response: '[\n  {"question": "How is Abhi related to Bati?", "answer": "Abhim   7% (1/15) 0:08:16
# is the grandmother of Mahe, and since Cand is married to Bati, and considering
# the relationships provided, Abhi\'s relation to Bati can be deduced through
# Cand. However, the direct link between Abhi and Bati requires understanding
# Abhi\'s position in the family. Given Abhi is the sister-in-law of Vaak and the
# grandmother of Mahe, without explicit information on how Abhi connects to Cand
# or Bati directly through blood or marriage, the'
# JSON parse error for object: Extra data: line 1 column 808 (char 807)━━━━━━━━   7% (1/15) 0:08:16
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Processing batch 8m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Parsing ratings response of length 1493m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Raw response: '[\n  {\n    "question": "Who among the following is the wife of 0m   7% (1/15) 0:08:16
# V?",\n    "answer": "Given V is the only uncle of T and is married, and Q is the
# mother-in-law of S, and P has only one son who is married to S, we can infer
# relationships but not directly determine V\'s wife without more specific
# connections. However, since V is from the second generation and is an uncle, and
# considering the family structure with three couples and equal males and females,
# V\'s wife would be one of the females in the fam'
# JSON parse error for object: Extra data: line 1 column 618 (char 617)━━━━━━━━   7% (1/15) 0:08:16
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Processing batch 9m━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Parsing ratings response of length 1388m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Raw response: '[\n  {"question": "How is the one who uses Nokia related to the 0m   7% (1/15) 0:08:16
# one who uses Vivo?", "answer": "The one who uses Nokia is the father of the one
# who uses Vivo. This can be deduced by analyzing the relationships between the
# family members and the phone brands they use.", "rating": 6},\n  {"question":
# "Which brand of phone does X use?", "answer": "X uses Vivo. This can be deduced
# by analyzing the relationships between the family members and the phone brands
# they use.", "rating": 5},\n  {"question": "W'
# JSON parse error for object: Extra data: line 1 column 278 (char 277)━━━━━━━━   7% (1/15) 0:08:16
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Processing batch 10━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Parsing ratings response of length 1600m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Raw response: '[\n  {"question": "If Radhey is the son-in-law of Krishna and    7% (1/15) 0:08:16
# Hari has an uncle, what is the relationship between Radhey and Hari?", "answer":
# "Radhey is the father of Hari because Radhey is the son-in-law of Krishna, and
# Krishna is the husband of Kanha, who belongs to the first generation of the
# family. Since Hari has an uncle and Gaur is the uncle of Hari, Radhey must be
# the father of Hari.", "rating": 6},\n  {"question": "Given that Gaur is
# unmarried and has a sister, and Hari has an uncle, wha'
# JSON parse error for object: Extra data: line 1 column 406 (char 405)━━━━━━━━   7% (1/15) 0:08:16
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Processing batch 3/4━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Sending batch request with 5 itemsm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:08:16INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:33 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:51 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:09INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:32INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
#   {"question": "Who is the brother-in-law's brother-in-law of Naasih?", ━━━━━   7% (1/15) 0:09:54
# "answer": "Qutub is the br...
# Response 2: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
#   {"question": "Given that Kat is the mother of Jay, and Cal is the father of    7% (1/15) 0:09:54
# Kat, what is the rel...
# Response 3: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
#   {"question": "Given the expression 'K@G$T#Y*U', where K is the son of G, T is m   7% (1/15) 0:09:54
# the brother of G, ...
# Response 4: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
#   {"question": "Given that one of the photographs is either of Suraj or Ankur, 0m   7% (1/15) 0:09:54
# and Ankur is not po...
# Response 5: [ ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
#   {"question": "Avnish and Avni are sisters. Asha is the brother-in-law of ━━   7% (1/15) 0:09:54
# Avnish, and Abish is th...
# Processing batch 11━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
# Parsing ratings response of length 1518m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% (1/15) 0:09:54
# Raw response: '[\n  {"question": "Who is the brother-in-law\'s brother-in-law ofm   7% (1/15) 0:09:54
# Naasih?", "answer": "Qutub is the brother-in-law\'s brother-in-law of Naasih
# because Naasih\'s brother-in-law is Madvan, and Madvan\'s brother-in-law is
# Qutub.", "rating": 8},\n  {"question": "What is the relationship between
# Madvan\'s sister\'s sister-in-law and Madvan\'s brother-in-law?", "answer":
# "Madvan\'s sister\'s sister-in-law is Omisha, and Madvan\'s brother-in-law is
# ...
# Parsing ratings response of length 3325━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:19
# Raw response: '[\n  {"question": "If Pranjal likes Pink and sits to the 90m━━  93% (14/15) 1:30:19
# immediate left of Garima, and Charu sits second to the right of Pranjal, how
# does this affect the seating arrangement?", "answer": "With Pranjal to the
# immediate left of Garima and Charu second to the right of Pranjal, we can deduce
# the following arrangement: ..., Pranjal, Garima, ?, Charu. Given that Garima
# likes Blue, we now have a segment of the seating arrangement that looks like:
# ..., Pranjal (Pink), Garima (Blue), ?, Charu. This helps'
# JSON parse error for object: Extra data: line 1 column 618 (char 617)m━━  93% (14/15) 1:30:19
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:19
# Processing batch 3/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:19
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:19
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:19INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:30 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:30:47INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:04:53 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:14 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:05:34 -:--:--INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
#   {"question": "Given that Sejal, who likes Black, sits two places away from   93% (14/15) 1:32:14
# Surbhi, and consideri...
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
#   {"question": "If Person A likes Red and Person B likes Grey, and the person   93% (14/15) 1:32:14
# who likes Red is an ...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
#   {"question": "In a triangle seating arrangement, if Pawan sits second to the 0m  93% (14/15) 1:32:14
# right of Krish, who...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
#   {"question": "Given that neither Harman nor Aparna likes Yellow, Piyush is an m  93% (14/15) 1:32:14
# immediate neighbor...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
#   {"question": "If Navya who likes Black and sits at the corner of the table is m  93% (14/15) 1:32:14
# two places away fr...
# Processing batch 11━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Parsing ratings response of length 3256━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Raw response: '[\n  {"question": "Given that Sejal, who likes Black, sits two   93% (14/15) 1:32:14
# places away from Surbhi, and considering previous constraints, how does this
# further refine the seating arrangement?", "answer": "With Sejal sitting two
# places away from Surbhi, and knowing Surbhi is at a corner, this means Sejal
# must be third in line from Surbhi\'s corner. Combining this with previous
# information about Neha and Krish\'s positions relative to each other and the
# corner, we start to see a more defined structure emerge, al'
# JSON parse error for object: Extra data: line 1 column 563 (char 562)m━━  93% (14/15) 1:32:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Processing batch 12━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Parsing ratings response of length 2584━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Raw response: '[\n  {"question": "If Person A likes Red and Person B likes Grey,m  93% (14/15) 1:32:14
# and the person who likes Red is an immediate neighbour of the person who likes
# Grey but doesn\'t sit at the corner of the table, what can be inferred about
# their seating positions?", "answer": "From the given statement, we can infer
# that Person A (who likes Red) and Person B (who likes Grey) are seated next to
# each other, but not at the corner of the table. This means they must be seated
# in the middle two seats, with Person A on one'
# JSON parse error for object: Extra data: line 1 column 544 (char 543)m━━  93% (14/15) 1:32:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Processing batch 13━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Parsing ratings response of length 2452━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Raw response: '[\n  {"question": "In a triangle seating arrangement, if Pawan   93% (14/15) 1:32:14
# sits second to the right of Krish, who likes Green, and there are three possible
# cases, how would the arrangement look like?", "answer": "The arrangement would
# have three possible cases: CASE I, CASE II, and CASE III, with different seating
# positions for Pawan and Krish. To determine the exact arrangement, we need to
# consider additional constraints and eliminate impossible cases through
# step-by-step logical deductions.", "rating": 7},'
# JSON parse error for object: Extra data: line 1 column 496 (char 495)m━━  93% (14/15) 1:32:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Processing batch 14━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Parsing ratings response of length 2299━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Raw response: '[\n  {"question": "Given that neither Harman nor Aparna likes   93% (14/15) 1:32:14
# Yellow, Piyush is an immediate neighbor of Aparna, and Harman doesn\'t like
# Golden, how would this affect the seating arrangement?", "answer": "This
# information would eliminate CASE I (A) and CASE III, and we would continue with
# CASE I (A) (B) as the final arrangement. We need to carefully examine the
# relationships between the individuals, their color preferences, and seating
# positions to deduce the final arrangement, ensuring that all '
# JSON parse error for object: Extra data: line 1 column 567 (char 566)m━━  93% (14/15) 1:32:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Processing batch 15━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Parsing ratings response of length 2682━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Raw response: '[\n  {"question": "If Navya who likes Black and sits at the ━━  93% (14/15) 1:32:14
# corner of the table is two places away from Dolsy, what are the possible seating
# arrangements?", "answer": "We need to consider the possible seating arrangements
# and eliminate the ones that contradict the given statements. We can start by
# placing Navya and Dolsy, and then add the other people to the seating
# arrangement.", "rating": 6},\n  {"question": "If only one person sits between
# Dolsy and the person who likes Purple, what can be infe'
# JSON parse error for object: Extra data: line 1 column 392 (char 391)m━━  93% (14/15) 1:32:14
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Processing batch 4/4━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Sending batch request with 5 items━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:14INFO:synthetic_data_kit.models.llm_client:Processing batch 1/1 with 5 requests
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:32:42INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:33:10INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:33:36INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:00INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# INFO:synthetic_data_kit.models.llm_client:Sending batch request to vLLM model Unsloth/Llama-3.3-70B-Instruct...
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42INFO:synthetic_data_kit.models.llm_client:Received response with status code: 200
# Received 5 responses
# Response 1: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
#   {"question": "If Arti likes Yellow and sits to the immediate left of Suhaas, 0m  93% (14/15) 1:34:42
# and Suhaas sits thi...
# Response 2: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
#   {"question": "If Prachi, who likes Blue, is neither an immediate neighbor of 0m  93% (14/15) 1:34:42
# Ajay nor Arti, and ...
# Response 3: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
#   {"question": "In a triangle seating arrangement, if Mishu who likes Red sits 0m  93% (14/15) 1:34:42
# two places away fro...
# Response 4: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
#   {"question": "If Sneha sits to the immediate right of Khushi and the person   93% (14/15) 1:34:42
# who likes Orange sit...
# Response 5: [ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
#   {
#     "question": "On a island where all inhabitants are either knights (who ━━  93% (14/15) 1:34:42
# always tell the tru...
# Processing batch 16━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Parsing ratings response of length 3260━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Raw response: '[\n  {"question": "If Arti likes Yellow and sits to the immediatem  93% (14/15) 1:34:42
# left of Suhaas, and Suhaas sits third to the left of Amrit, how will the seating
# arrangement change?", "answer": "With Arti sitting to the immediate left of
# Suhaas, and Suhaas sitting third to the left of Amrit, the seating arrangement
# will undergo significant changes. Arti\'s position will be fixed relative to
# Suhaas, and Suhaas\' position will be fixed relative to Amrit. This will lead to
# the elimination of some possible cases and '
# JSON parse error for object: Extra data: line 1 column 597 (char 596)m━━  93% (14/15) 1:34:42
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Processing batch 17━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Parsing ratings response of length 3494━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Raw response: '[\n  {"question": "If Prachi, who likes Blue, is neither an ━━  93% (14/15) 1:34:42
# immediate neighbor of Ajay nor Arti, and both the person who likes Red and the
# person who likes Yellow are immediate neighbors of the person who likes Black,
# how can we use this information to solve the seating arrangement?", "answer":
# "This information provides critical constraints. Knowing Prachi\'s position
# relative to Ajay and Arti, and the relationship between the individuals who like
# Red, Yellow, and Black, allows us to make signifi'
# JSON parse error for object: Extra data: line 1 column 794 (char 793)m━━  93% (14/15) 1:34:42
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Processing batch 18━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Parsing ratings response of length 3450━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Raw response: '[\n  {"question": "In a triangle seating arrangement, if Mishu   93% (14/15) 1:34:42
# who likes Red sits two places away from the person who likes White, and the
# person who likes White sits at the corner of the table, what can we infer about
# the possible seating arrangements?", "answer": "From the given statement, we can
# infer that there are two possible cases for the seating arrangement. We need to
# consider the position of Mishu and the person who likes White, and then analyze
# the possible arrangements of the other in'
# JSON parse error for object: Extra data: line 1 column 680 (char 679)m━━  93% (14/15) 1:34:42
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Processing batch 19━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Parsing ratings response of length 2651━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Raw response: '[\n  {"question": "If Sneha sits to the immediate right of Khushim  93% (14/15) 1:34:42
# and the person who likes Orange sits second to the right of Sneha, who sits to
# the immediate left of the person who likes Orange?", "answer": "To solve this,
# we start by placing Sneha to the right of Khushi. Then, since the person who
# likes Orange sits second to the right of Sneha, there must be one person between
# Sneha and the person who likes Orange. Therefore, the person who sits to the
# immediate left of the person who likes Ora'
# JSON parse error for object: Extra data: line 1 column 525 (char 524)5m  0% 0:08:25 -:--:--:42
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Processing batch 20━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Parsing ratings response of length 4281━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Raw response: '[\n  {\n    "question": "On a island where all inhabitants are   93% (14/15) 1:34:42
# either knights (who always tell the truth) or knaves (who always lie), if a
# person says \'I am a knave,\' what can be deduced about this person?",\n
# "answer": "If the person says \'I am a knave,\' and assuming they are a knight
# (tells the truth), then their statement must be false, which leads to a
# contradiction because a knight cannot lie. Therefore, the person must actually
# be a knave because, as a liar, they would falsely claim to be '
# JSON parse error for object: Extra data: line 1 column 556 (char 555)m━━  93% (14/15) 1:34:42
# Successfully parsed 5 items in JSON array━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Rating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:08:25 -:--:--:42
# Rated 100 QA pairs
# Retained 75 pairs (threshold: 7.0)━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# Average score: 7.4m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# ✓ Curated ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━  93% (14/15) 1:34:42
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims_qa_pairs.json ->
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims_qa_pairs_cleaned.json
# Curating QA pairs ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% (15/15) 1:34:42) 1:34:4232m (14/15) 1:34:42
#
# ==================================================
# Curation Summary (threshold: 7.0):
# Total files: 15
# Successful: 14
# Failed: 1
# ==================================================
# ⚠️  Completed with 1 errors

# %% [markdown]
# ### Curating and Quality Filtering
#
# This command uses the **curate** function to filter generated Q&A pairs based on quality:
# - Evaluates each Q&A pair using quality metrics
# - Filters pairs with quality score above threshold (7.0/10)
# - Removes low-quality, inconsistent, or malformed pairs
# - Saves curated data to `data/curated/`
#
# This ensures only high-quality synthetic data is used for fine-tuning.

# %%
# !synthetic-data-kit save-as ./data/curated/ --format ft
# Out:
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Loading config from: /usr/local/lib/python3.12/dist-packages/synthetic_data_kit/config.yaml
# Config has LLM provider set to: api-endpoint
# Processing directory: ./data/curated/ for format conversion to ft
# Found 14 JSON files to convert to ft format
# ✓ Blood-Relations-Questions-and-Answers_qa_pairs_cleaned.json
# ✓ Blood_Relation_PDF_Set_1_qa_pairs_cleaned.json
# ✓ Blood_Relation_PDF_Set_2_qa_pairs_cleaned.json
# ✓ Blood_Relation_Quiz_36_qa_pairs_cleaned.json
# ✓ Liar_Truth_qa_pairs_cleaned.json
# ✓ blood-relation-free-pdf-for-upcoming-prelims-exams_qa_pairs_cleaned.json
# ✓
# blood-relation-ultra-bundle-pdf-for-upcoming-bank-prelims-exams_qa_pairs_cleaned
# .json
# ✓ blood_relations_medium_100_qa_pairs_cleaned.json
# ✓
# circular-seating-arrangement-free-pdf-for-upcoming-prelims-exams_qa_pairs_cleane
# d.json
# ✓
# linear-seating-arrangement-free-pdf-for-upcoming-prelims-exams_qa_pairs_cleaned.
# json
# ✓ logical-reasoning-2017-12-02_qa_pairs_cleaned.json
# ✓
# parallel-rows-seating-arrangement-free-pdf-for-upcoming-prelims-exams_qa_pairs_c
# leaned.json
# ✓ seating_arrangements_medium_100_qa_pairs_cleaned.json
# ✓
# triangle-seating-arrangement-with-two-variable-questions-specially-for-sbi-po-pr
# elims_qa_pairs_cleaned.json
#
# ==================================================
# Format Conversion Summary (ft, json):
# Total files: 14
# Successful: 14
# Failed: 0
# ==================================================
# ✅ All files converted successfully!

# %% [markdown]
# ### Converting to Fine-Tuning Format
#
# This command uses the **save-as** function to convert curated Q&A pairs to fine-tuning format:
# - Reads curated JSON files from `data/curated/`
# - Converts to format `ft` (fine-tuning format with messages structure)
# - Outputs are saved to `data/final/` with proper conversation format
# - The resulting format is compatible with standard fine-tuning pipelines
#
# Successfully converted 2 files to fine-tuning format.

# %%
import json
import glob
from pathlib import Path
from datasets import Dataset

# ===== CONFIGURATION =====
data_dir = "./data/final"  # Change this to your data directory

# ===== STEP 1: Find all FT files =====
data_path = Path(data_dir)
ft_files = glob.glob(str(data_path / "*.json"))

# ===== STEP 2: Load and convert all files =====
all_data = []

for file_path in ft_files:
    # Load the JSON file
    with open(file_path, 'r') as f:
        ft_data = json.load(f)
    
    # Convert each item
    for item in ft_data:
        if 'messages' not in item:
            continue
        
        # Extract only user and assistant messages
        conversation = []
        for msg in item['messages']:
            if msg['role'] == 'user' or msg['role'] == 'assistant':
                conversation.append({
                    "role": msg['role'],
                    "content": msg['content']
                })
        
        # Add to our data if we have at least one exchange
        if len(conversation) > 0:
            all_data.append({
                "conversations": conversation
            })

print(f"\n🎯 Total conversations: {len(all_data)}")

# ===== STEP 3: Create HuggingFace Dataset =====
dataset = Dataset.from_list(all_data)

# ===== STEP 4: Preview the data =====
print(json.dumps(dataset[0], indent=2))
# Out:
# 🎯 Total conversations: 1038
# {
#   "conversations": [
#     {
#       "content": "In Problem 1, who is the spouse of Tara and how is Deepak related to Rekha?",
#       "role": "user"
#     },
#     {
#       "content": "To find the spouse of Tara and the relationship between Deepak and Rekha, we analyze the clues. From clue 4, Tara is the wife of Rekha, meaning Rekha is the spouse of Tara. For Deepak's relation to Rekha, since Deepak is the son of Kabir (clue 1) and Tara is the daughter of Kabir (clue 3) and also the wife of Rekha, this makes Deepak the brother of Tara, and thus, Deepak is the brother-in-law of Rekha.",
#       "role": "assistant"
#     }
#   ]
# }

# %% [markdown]
# ### Loading and Converting Data to HuggingFace Dataset
#
# This cell performs comprehensive data processing:
#
# 1. **Finding Files**: Locates all JSON files in `data/final/` directory
# 2. **Loading Data**: Reads each JSON file containing fine-tuning formatted data
# 3. **Format Conversion**: Extracts user and assistant messages from the fine-tuning format
# 4. **Structuring Conversations**: Creates a standardized conversation format with role-content pairs
# 5. **Creating Dataset**: Converts the processed data into a HuggingFace Dataset object
#
# The output shows 74 total conversations were successfully loaded and formatted. The preview displays a sample conversation showing a knight-and-knave logic puzzle with its solution.

# %% [markdown]
# ## Fine-Tuning
#
# ### Note: Please remember to shutdown the vLLM instance!

# %%
import os
import json
import glob
import torch
import shutil
from pathlib import Path
from datasets import Dataset

# %% [markdown]
# ### Importing Standard Libraries
#
# Imports essential Python libraries for fine-tuning:
# - `os`, `json`, `glob`: File system operations and JSON handling
# - `torch`: PyTorch deep learning framework
# - `shutil`: File operations
# - `Path`: Path manipulation
# - `Dataset`: HuggingFace datasets library for data handling

# %%
from unsloth import FastLanguageModel
from unsloth.chat_templates import get_chat_template, standardize_sharegpt, train_on_responses_only
from trl import SFTConfig, SFTTrainer
from transformers import DataCollatorForSeq2Seq
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Skipping import of cpp extensions due to incompatible torch version 2.9.0a0+git1c57644 for torchao version 0.14.1             Please see https://github.com/pytorch/ao/issues/2919 for more info
# #### Unsloth: `hf_xet==1.1.10` and `ipykernel>6.30.1` breaks progress bars. Disabling for now in XET.
# #### Unsloth: To re-enable progress bars, please downgrade to `ipykernel==6.30.1` or wait for a fix to
# https://github.com/huggingface/xet-core/issues/526
# INFO 10-27 21:32:15 [__init__.py:225] Automatically detected platform rocm.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ### Importing Unsloth and Training Libraries
#
# Imports specialized libraries for efficient fine-tuning:
# - `FastLanguageModel` from Unsloth: Optimized model loading and training
# - `get_chat_template`, `standardize_sharegpt`, `train_on_responses_only`: Chat formatting utilities
# - `SFTConfig`, `SFTTrainer`: Supervised fine-tuning configuration and trainer from TRL
# - `DataCollatorForSeq2Seq`: Handles batching and padding for sequence-to-sequence training

# %% [markdown]
# ### Setup Unsloth model and tokenizer for ROCm without bitsandbytes

# %%
max_seq_length = 1024
dtype = torch.bfloat16  # Explicit bfloat16 for ROCm
load_in_4bit = False  

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/llama-3-8b-instruct",
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
    device_map="auto",
    torch_dtype=torch.bfloat16,  # Explicit for ROCm
    trust_remote_code=True,
    #fast_inference=True,
)

print(f"✅ Loaded: unsloth/llama-3-8b-instruct (bfloat16, ROCm compatible)")

# Add LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r=16,  # Higher rank for 70B model
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                   "gate_proj", "up_proj", "down_proj"],
    lora_alpha=32,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
    use_rslora=False,
    loftq_config=None,
)
# Out:
# Unsloth: AMD currently is not stable with 4bit bitsandbytes. Disabling for now.
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2025.10.9: Fast Llama patching. Transformers: 4.56.2. vLLM: 0.11.1rc3.dev39+gf417746ad.rocm700.
#    \\   /|    . Num GPUs = 1. Max memory: 191.688 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0a0+git1c57644. ROCm Toolkit: 7.0.51831-a3e329ad8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# `torch_dtype` is deprecated! Use `dtype` instead!
# [2025-10-28 03:07:33] INFO modeling.py:987: We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Loaded: unsloth/llama-3-8b-instruct (bfloat16, ROCm compatible)
# Unsloth 2025.10.9 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### Loading Llama-3.3-70B Model with LoRA
#
# This cell sets up the model for efficient fine-tuning on AMD ROCm hardware:
#
# **Model Configuration:**
# - Model: Llama-3.3-70B-Instruct (70 billion parameters)
# - Data type: bfloat16 for ROCm compatibility
# - No quantization (load_in_4bit=False) to avoid bitsandbytes dependency
# - Max sequence length: 1024 tokens
#
# **LoRA (Low-Rank Adaptation) Configuration:**
# - Rank (r): 64 - Higher rank for the large 70B model
# - Target modules: All attention and MLP layers (q_proj, k_proj, v_proj, o_proj, gate_proj, up_proj, down_proj)
# - LoRA alpha: 64
# - Dropout: 0 (no dropout)
# - Gradient checkpointing: "unsloth" for memory efficiency
#
# LoRA enables efficient fine-tuning by only training small adapter layers instead of the entire 70B model, making it feasible to train on a single AMD MI300X GPU with 192GB HBM3 memory.

# %%
"""Prepare dataset with proper chat template and tensor compatibility"""
print("🔧 Preparing dataset for training...")

# Set chat template
tokenizer = get_chat_template(tokenizer, chat_template="llama-3.3")

# Ensure pad token is set
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Formatting function that ensures proper tensor conversion
def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = []
    
    for convo in convos:
        # Ensure conversation is in correct format
        if isinstance(convo, list) and all(isinstance(msg, dict) for msg in convo):
            text = tokenizer.apply_chat_template(convo, tokenize=False, add_generation_prompt=False)
            texts.append(text)
        else:
            print(f"⚠️  Skipping malformed conversation: {type(convo)}")
            continue
    
    return {"text": texts}

dataset = standardize_sharegpt(dataset)

dataset = dataset.map(formatting_prompts_func, batched=True, remove_columns=dataset.column_names)

dataset = dataset.filter(lambda x: len(x["text"].strip()) > 0)

print(f"✅ Prepared {len(dataset)} valid examples for training")

# Show sample
if len(dataset) > 0:
    print(f"📝 Sample formatted text:")
    print(dataset["text"][0][:200] + "...")
# Out:
# 🔧 Preparing dataset for training...
# Unsloth: Standardizing formats (num_proc=20):   0%|          | 0/1038 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1038 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1038 [00:00<?, ? examples/s]
# ✅ Prepared 1038 valid examples for training
# 📝 Sample formatted text:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 July 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# In Problem 1, who is th...

# %% [markdown]
# ### Preparing Dataset with Chat Template
#
# This cell formats the dataset for fine-tuning:
#
# **Steps:**
# 1. **Set Chat Template**: Applies Llama-3.1 chat template formatting
# 2. **Configure Padding**: Sets pad token to eos token if not already set
# 3. **Format Conversations**: The `formatting_prompts_func` function:
#    - Takes raw conversations from the dataset
#    - Applies the chat template to format them properly
#    - Validates conversation structure (list of dicts with role/content)
#    - Filters out malformed conversations
# 4. **Standardize Format**: Uses `standardize_sharegpt` to normalize the data structure
# 5. **Apply Formatting**: Maps the formatting function across all examples
# 6. **Remove Empty**: Filters out any empty or invalid formatted texts
#
# The output shows 74 valid examples were successfully prepared. A sample of the formatted text is displayed, showing the proper Llama-3.1 chat template structure with system, user, and assistant headers.

# %%
"""Train model with ROCm-optimized settings"""
# Ensure tokenizer has proper padding
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id

# Setup trainer with ROCm-friendly settings and proper data handling
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    data_collator=DataCollatorForSeq2Seq(tokenizer=tokenizer, padding=True),
    packing=False,
    args=SFTConfig(
        per_device_train_batch_size=64,  # 🚀 MI300X can handle this with 192GB HBM3!
        gradient_accumulation_steps=16,   # Effective batch size = 8*2 = 16
        warmup_steps=10,
        num_train_epochs=1,
        learning_rate=1e-4,
        logging_steps=1,
        optim="adamw_8bit",  # Pure torch optimizer
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="logical_reasoning_rocm_outputs",
        report_to="none",
        bf16=True,
        dataloader_pin_memory=False,
        remove_unused_columns=True,  # Remove unused columns to avoid tensor issues
        gradient_checkpointing=True,
        dataloader_num_workers=0,  # Single worker for ROCm stability
    ),
)

# Train only on responses
trainer = train_on_responses_only(
    trainer,
    instruction_part="<|start_header_id|>user<|end_header_id|>\n\n",
    response_part="<|start_header_id|>assistant<|end_header_id|>\n\n",
)

FastLanguageModel.for_training(model)
trainer_stats = trainer.train()


trainer_stats = trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=24):   0%|          | 0/1038 [00:00<?, ? examples/s]
# Map (num_proc=24):   0%|          | 0/1038 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,038 | Num Epochs = 1 | Total steps = 33
# O^O/ \_/ \    Batch size per device = 32 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (32 x 1 x 1) = 32
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
#     <div>
#
#       <progress value='33' max='33' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33/33 00:38, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.570300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.625000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.562500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.671900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.531200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.562500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.429700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.281200</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.375000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.328100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.320300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.148400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.109400</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.203100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.195300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.187500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.992200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.250000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.070300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.250000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.140600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.179700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.179700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.226600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.007800</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.078100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.140600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.164100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.148400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.148400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.101600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.093800</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Will smartly offload gradients to save VRAM!
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,038 | Num Epochs = 1 | Total steps = 33
# O^O/ \_/ \    Batch size per device = 32 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (32 x 1 x 1) = 32
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
#     <div>
#
#       <progress value='33' max='33' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33/33 00:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.031200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.062500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.996100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.171900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.078100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.117200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.046900</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.996100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.078100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.039100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.062500</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.894500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.906200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.964800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.949200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.988300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.812500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.031200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.882800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.062500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.980500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.992200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.007800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.070300</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.863300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.929700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.847700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.984400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.996100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.964800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.980500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.914100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.812500</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ### Training the Model with ROCm-Optimized Settings
#
# This cell configures and executes the fine-tuning process:
#
# **Training Configuration (SFTConfig):**
# - **Batch size**: 64 per device - leveraging the AMD MI300X's massive 192GB HBM3 memory
# - **Gradient accumulation**: 1 step
# - **Warmup**: 5 steps
# - **Epochs**: 1 full pass through the dataset
# - **Learning rate**: 1e-4
# - **Optimizer**: adamw_8bit for memory efficiency
# - **Precision**: bf16 (bfloat16) for ROCm
# - **Gradient checkpointing**: Enabled for memory efficiency
#
# **Special Training Mode:**
# Uses `train_on_responses_only` to compute loss only on the assistant's responses, not on the user's questions. This focuses the model on learning to generate accurate answers rather than memorizing the input format.
#
# **Key Features:**
# - DataCollatorForSeq2Seq handles variable-length sequences with proper padding
# - No packing to preserve conversation structure
# - Single dataloader worker for ROCm stability
# - Gradient checkpointing via Unsloth for memory optimization
#
# The model is then trained on the 1038 logical reasoning conversations.

# %%
"""Save the trained model"""
print("\n💾 SAVING ROCM-TRAINED MODEL")

# Save LoRA adapters
lora_path = "logical_reasoning_rocm_lora"
model.save_pretrained(lora_path)
tokenizer.save_pretrained(lora_path)
print(f"✅ LoRA adapters saved to: {lora_path}")

# Save merged model
merged_path = "logical_reasoning_rocm_merged"
print("🔄 Saving merged model...")
model.save_pretrained_merged(merged_path, tokenizer, save_method="merged_16bit")
print(f"✅ Merged model saved to: {merged_path}")

print(f"\n🎉 ROCM MODEL READY!")
# Out:
# 💾 SAVING ROCM-TRAINED MODEL
# ✅ LoRA adapters saved to: logical_reasoning_rocm_lora
# 🔄 Saving merged model...
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Unsloth: Copying 4 files from cache to `logical_reasoning_rocm_merged`: 100%|██████████████████████████████████████████████████████████████████| 4/4 [00:06<00:00,  1.68s/it]
# Successfully copied all 4 files from cache to `logical_reasoning_rocm_merged`
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 73584.28it/s]
# Unsloth: Merging weights into 16bit: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:32<00:00,  8.19s/it]
# Unsloth: Merge process complete. Saved to `/workspace/AIAC/logical_reasoning/logical_reasoning_rocm_merged`
# ✅ Merged model saved to: logical_reasoning_rocm_merged
#
# 🎉 ROCM MODEL READY!

# %% [markdown]
# ### Saving the Fine-Tuned Model
#
# This cell saves the trained model in two formats:
#
# 1. **LoRA Adapters** (`logical_reasoning_rocm_lora/`):
#    - Saves only the trained LoRA adapter weights (lightweight, ~few hundred MB)
#    - Can be loaded later with the base model
#    - Useful for sharing or deploying with the original base model
#
# 2. **Merged Model** (`logical_reasoning_rocm_merged/`):
#    - Merges LoRA adapters back into the base model
#    - Creates a standalone model with all weights
#    - Saved in 16-bit precision for better quality
#    - Ready for immediate inference without loading adapters
#
# Both formats include the tokenizer configuration. The merged model is production-ready and can be used directly for generating answers to logical reasoning questions.

# %%
from huggingface_hub import notebook_login

# This will display a widget to enter your access token.
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
